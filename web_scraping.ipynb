# %%
from selenium import webdriver
import pandas as pd
import requests
import json
import time

# %%
def scrape_ad(driver, url):
    driver.get(url)
    return pd.read_html(driver.page_source)

# %%
driver = webdriver.Chrome()

# load dataframe from existing csv file or create new one from scratch
try:
    df = pd.read_csv('data/dump_df_full.csv').set_index('Unnamed: 0')
except:
    df = pd.DataFrame()

# set page number
n = 1

while True:
    r = requests.get(f'https://www.immoweb.be/en/search-results/house-and-apartment/for-rent?countries=BE&page={n}&orderBy=newest')
    list_ads = r.json()["results"]
    for ad in list_ads:

        # create dictionary for building df1
        property = {}
        features = {}
        features["API id"] = ad["id"]
        features["API property type"] = ad["property"]["type"].lower()
        features["API subtype"] = ad["property"]["subtype"].lower()
        features["API number bedrooms"] = ad["property"]["bedroomCount"]
        features["API number rooms"] = ad["property"]["roomCount"]
        features["API region"] = ad["property"]["location"]["region"]
        features["API province"] = ad["property"]["location"]["province"]
        features["API locality"] = ad["property"]["location"]["locality"]
        features["API postalcode"] = ad["property"]["location"]["postalCode"]
        features["API street"] = ad["property"]["location"]["street"]
        features["API full address"] = ad["property"]["location"]["street"], ad["property"]["location"]["number"], ad["property"]["location"]["postalCode"], ad["property"]["location"]["locality"]
        features["API floor"] = ad["property"]["location"]["floor"]
        features["API net habitable surface"] = ad["property"]["netHabitableSurface"]
        features["API rent"] = ad["transaction"]["rental"]["monthlyRentalPrice"]
        features["API monthly costs"] = ad["transaction"]["rental"]["monthlyRentalCosts"]

        # rebuild URL for indexing and scraping with Selenium
        url = f'https://www.immoweb.be/en/classified/{features["API property type"]}/for-rent/{features["API locality"]}/{features["API postalcode"]}/{features["API id"]}'

        # avoid duplicates
        if url in df.index:
            continue

        # build df1
        property[url] = features
        df1 = pd.DataFrame.from_dict(property)
        df1 = df1.T

        # create df2 with Selenium
        df2 = None
        try:
            df2 = scrape_ad(driver, url)
        except:
            time.sleep(3)
            try:
                df2 = scrape_ad(driver, url)
            except:
                print(f'Failed to scrape this ad: {url}')

        # transform df2
        if df2 is not None:
            df2 = pd.concat(df2).reset_index(drop=True)
            df2 = df2.set_index(0)
            df2.columns = [url]
            df2 = df2[~df2.index.duplicated(keep='first')] # if time allows try: df2 = df2.loc[~df2.index.duplicated()]
            df2 = df2.T

            # filter columns
            columns_to_keep = [
                'Number of floors',
                'Building condition',
                'Number of frontages',
                'Outdoor parking spaces',
                'Living room surface',
                'Kitchen type',
                'Kitchen surface',
                'Bedroom 1 surface',
                'Bedroom 2 surface',
                'Bathrooms',
                'Toilets',
                'Furnished',
                'Terrace surface',
                'Elevator',
                'Primary energy consumption',
                'Energy class',
                'Yearly theoretical total energy consumption',
                'Heating type',
                'Double glazing',
                'Dressing room',
                'Shower rooms',
                'Office',
                'Professional space',
                'Armored door',
                'Accessible for disabled people',
                'Intercom',
                'Secure access / alarm',
                'TV cable',
                'Visio phone',
                'Jacuzzi',
                'Sauna',
                'Swimming pool',
                'Internet',
                'Heat pump',
                'Photovoltaic solar panels',
                'Thermic solar panels',
                'Common water heater',
                'Type of building',
                'Construction year',
                'Surroundings type',
                'Covered parking spaces',
                'Basement',
                'Flood zone type',
                'Small pet-friendly',
                'Living room'
            ]
            # columns = [col for col in df2.columns if isinstance(col, str) and 'Insure' not in col]
            columns = [col for col in df2.columns if col in columns_to_keep]
            df2 = df2[columns]

            # assemble df1 and df2
            df3 = pd.concat([df1, df2], axis=1)
            
            # add data in df
            df = pd.concat([df, df3])

        else:
            df = pd.concat([df, df1])

        # save collected data to a csv file
        df.to_csv('data/dump_df_full.csv')

    # go to next page
    n += 1

    # next two lines only for testing on a limited number of pages:
    if n == 4:
        break

driver.close()
df.shape # expect 30 ads per page and 60 columns
# Out:
# (90, 60)

# %%
df
# Out:
#                                                     API floor  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...        0.0
# https://www.immoweb.be/en/classified/apartment/...        1.0
# https://www.immoweb.be/en/classified/apartment/...        7.0
# https://www.immoweb.be/en/classified/apartment/...        1.0
# https://www.immoweb.be/en/classified/apartment/...        2.0
# ...                                                       ...
# https://www.immoweb.be/en/classified/apartment/...        0.0
# https://www.immoweb.be/en/classified/apartment/...        4.0
# https://www.immoweb.be/en/classified/house/for-...        NaN
# https://www.immoweb.be/en/classified/house/for-...        NaN
# https://www.immoweb.be/en/classified/apartment/...        1.0
#
#                                                                                      API full address  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...      ('Avenue Milcamps', '4', '1040', 'Etterbeek')
# https://www.immoweb.be/en/classified/apartment/...     ('La Distillerie', '1', '6593', 'Macquenoise')
# https://www.immoweb.be/en/classified/apartment/...                 (None, None, '1070', 'Anderlecht')
# https://www.immoweb.be/en/classified/apartment/...                  ('Dorp', '78', '2230', 'Herselt')
# https://www.immoweb.be/en/classified/apartment/...     ('Rue de La Halle', '17C/2.3', '7000', 'Mons')
# ...                                                                                               ...
# https://www.immoweb.be/en/classified/apartment/...         ('Mellepontweg', '9,', '9230', 'Wetteren')
# https://www.immoweb.be/en/classified/apartment/...  ('Rue Batonnier Braffort', '39', '1040', 'Ette...
# https://www.immoweb.be/en/classified/house/for-...              ('Postwegel', '2,', '8470', 'Gistel')
# https://www.immoweb.be/en/classified/house/for-...       ('Beverenstraat', '12,', '8830', 'Hooglede')
# https://www.immoweb.be/en/classified/apartment/...           ('Ezelstraat', '141,', '8000', 'Brugge')
#
#                                                       API id API locality  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...  10015891    Etterbeek
# https://www.immoweb.be/en/classified/apartment/...  10015889  Macquenoise
# https://www.immoweb.be/en/classified/apartment/...  10015880   Anderlecht
# https://www.immoweb.be/en/classified/apartment/...   9961742      Herselt
# https://www.immoweb.be/en/classified/apartment/...  10015876         Mons
# ...                                                      ...          ...
# https://www.immoweb.be/en/classified/apartment/...  10015665     Wetteren
# https://www.immoweb.be/en/classified/apartment/...  10015664    Etterbeek
# https://www.immoweb.be/en/classified/house/for-...  10015662       Gistel
# https://www.immoweb.be/en/classified/house/for-...  10015661     Hooglede
# https://www.immoweb.be/en/classified/apartment/...  10015660       Brugge
#
#                                                     API monthly costs  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...               50.0
# https://www.immoweb.be/en/classified/apartment/...              200.0
# https://www.immoweb.be/en/classified/apartment/...               25.0
# https://www.immoweb.be/en/classified/apartment/...                NaN
# ...                                                               ...
# https://www.immoweb.be/en/classified/apartment/...               50.0
# https://www.immoweb.be/en/classified/apartment/...              120.0
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/apartment/...               30.0
#
#                                                     API net habitable surface  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                       60.0
# https://www.immoweb.be/en/classified/apartment/...                      130.0
# https://www.immoweb.be/en/classified/apartment/...                      120.0
# https://www.immoweb.be/en/classified/apartment/...                      150.0
# https://www.immoweb.be/en/classified/apartment/...                       87.0
# ...                                                                       ...
# https://www.immoweb.be/en/classified/apartment/...                        NaN
# https://www.immoweb.be/en/classified/apartment/...                       82.0
# https://www.immoweb.be/en/classified/house/for-...                      110.0
# https://www.immoweb.be/en/classified/house/for-...                      150.0
# https://www.immoweb.be/en/classified/apartment/...                       65.0
#
#                                                     API number bedrooms  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                    1
# https://www.immoweb.be/en/classified/apartment/...                    3
# https://www.immoweb.be/en/classified/apartment/...                    3
# https://www.immoweb.be/en/classified/apartment/...                    3
# https://www.immoweb.be/en/classified/apartment/...                    2
# ...                                                                 ...
# https://www.immoweb.be/en/classified/apartment/...                    2
# https://www.immoweb.be/en/classified/apartment/...                    2
# https://www.immoweb.be/en/classified/house/for-...                    0
# https://www.immoweb.be/en/classified/house/for-...                    3
# https://www.immoweb.be/en/classified/apartment/...                    2
#
#                                                     API number rooms  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
# ...                                                              ...
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
# https://www.immoweb.be/en/classified/house/for-...               NaN
# https://www.immoweb.be/en/classified/house/for-...               NaN
# https://www.immoweb.be/en/classified/apartment/...               NaN
#
#                                                     API postalcode  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...            1040
# https://www.immoweb.be/en/classified/apartment/...            6593
# https://www.immoweb.be/en/classified/apartment/...            1070
# https://www.immoweb.be/en/classified/apartment/...            2230
# https://www.immoweb.be/en/classified/apartment/...            7000
# ...                                                            ...
# https://www.immoweb.be/en/classified/apartment/...            9230
# https://www.immoweb.be/en/classified/apartment/...            1040
# https://www.immoweb.be/en/classified/house/for-...            8470
# https://www.immoweb.be/en/classified/house/for-...            8830
# https://www.immoweb.be/en/classified/apartment/...            8000
#
#                                                    API property type  ...  \
# Unnamed: 0                                                            ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# ...                                                              ...  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
# https://www.immoweb.be/en/classified/house/for-...             house  ...
# https://www.immoweb.be/en/classified/house/for-...             house  ...
# https://www.immoweb.be/en/classified/apartment/...         apartment  ...
#
#                                                    Jacuzzi Sauna  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# https://www.immoweb.be/en/classified/apartment/...      No    No
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# ...                                                    ...   ...
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
# https://www.immoweb.be/en/classified/house/for-...     NaN   NaN
# https://www.immoweb.be/en/classified/house/for-...     NaN   NaN
# https://www.immoweb.be/en/classified/apartment/...     NaN   NaN
#
#                                                     Swimming pool Internet  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...            NaN      NaN
# https://www.immoweb.be/en/classified/apartment/...            NaN      NaN
# https://www.immoweb.be/en/classified/apartment/...            NaN      NaN
# https://www.immoweb.be/en/classified/apartment/...             No       No
# https://www.immoweb.be/en/classified/apartment/...            NaN      Yes
# ...                                                           ...      ...
# https://www.immoweb.be/en/classified/apartment/...             No      NaN
# https://www.immoweb.be/en/classified/apartment/...            NaN      NaN
# https://www.immoweb.be/en/classified/house/for-...            NaN      NaN
# https://www.immoweb.be/en/classified/house/for-...            NaN      NaN
# https://www.immoweb.be/en/classified/apartment/...            NaN      NaN
#
#                                                    Photovoltaic solar panels  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# https://www.immoweb.be/en/classified/apartment/...                        No
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# ...                                                                      ...
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# https://www.immoweb.be/en/classified/apartment/...                       NaN
# https://www.immoweb.be/en/classified/house/for-...                       NaN
# https://www.immoweb.be/en/classified/house/for-...                       NaN
# https://www.immoweb.be/en/classified/apartment/...                       NaN
#
#                                                     Thermic solar panels  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# https://www.immoweb.be/en/classified/apartment/...                    No
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# ...                                                                  ...
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# https://www.immoweb.be/en/classified/apartment/...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/house/for-...                   NaN
# https://www.immoweb.be/en/classified/apartment/...                   NaN
#
#                                                     Common water heater  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                  NaN
# https://www.immoweb.be/en/classified/apartment/...                  NaN
# https://www.immoweb.be/en/classified/apartment/...                  NaN
# https://www.immoweb.be/en/classified/apartment/...                   No
# https://www.immoweb.be/en/classified/apartment/...                   No
# ...                                                                 ...
# https://www.immoweb.be/en/classified/apartment/...                  NaN
# https://www.immoweb.be/en/classified/apartment/...                  NaN
# https://www.immoweb.be/en/classified/house/for-...                  NaN
# https://www.immoweb.be/en/classified/house/for-...                  NaN
# https://www.immoweb.be/en/classified/apartment/...                  NaN
#
#                                                       Type of building  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                 NaN
# https://www.immoweb.be/en/classified/apartment/...                 NaN
# https://www.immoweb.be/en/classified/apartment/...                 NaN
# https://www.immoweb.be/en/classified/apartment/...            All kind
# https://www.immoweb.be/en/classified/apartment/...  Apartment building
# ...                                                                ...
# https://www.immoweb.be/en/classified/apartment/...                 NaN
# https://www.immoweb.be/en/classified/apartment/...                 NaN
# https://www.immoweb.be/en/classified/house/for-...                 NaN
# https://www.immoweb.be/en/classified/house/for-...                 NaN
# https://www.immoweb.be/en/classified/apartment/...                 NaN
#
#                                                    Flood zone type  \
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...             NaN
# https://www.immoweb.be/en/classified/apartment/...             NaN
# https://www.immoweb.be/en/classified/apartment/...             NaN
# https://www.immoweb.be/en/classified/apartment/...  Non flood zone
# https://www.immoweb.be/en/classified/apartment/...  Non flood zone
# ...                                                            ...
# https://www.immoweb.be/en/classified/apartment/...             NaN
# https://www.immoweb.be/en/classified/apartment/...             NaN
# https://www.immoweb.be/en/classified/house/for-...             NaN
# https://www.immoweb.be/en/classified/house/for-...             NaN
# https://www.immoweb.be/en/classified/apartment/...             NaN
#
#                                                    Small pet-friendly
# Unnamed: 0
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...                Yes
# ...                                                               ...
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/apartment/...                NaN
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/house/for-...                NaN
# https://www.immoweb.be/en/classified/apartment/...                NaN
#
# [90 rows x 60 columns]
